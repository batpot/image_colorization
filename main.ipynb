# %%
import torch
import numpy as np
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
from skimage import io, color
from skimage.color import rgb2lab

# %%
# transforming RGB into L*a*b* color space: we use the L channel as input and the a, b channels as target output
class colorize_dataset(Dataset):
    def __init__(self, transforms=None):
        self.transforms = transforms

    def __getitem__(self, index):
        img_rgb = Image.open('IMG_3965.JPG').convert("RGB") #self.paths[index]

        img_rgb = self.transforms(img_rgb)
        img_rgb = np.asarray(img_rgb)

        img_lab = rgb2lab(img_rgb)

        L = img_lab[:, :, 0] / 100.0  # Normalize L channel to [0,1]
        ab = (img_lab[:, :, 1:3] + 128) / 255.0  # Normalize a and b to [0,1]

        L = torch.from_numpy(L).unsqueeze(0).float()         # shape: 1 x H x W
        ab = torch.from_numpy(ab).permute(2, 0, 1).float()   # shape: 2 x H x W

        return {'L': L, 'ab': ab}

# %%
#While the model works on any size image, we trained it on 224x224 pixel images and thus it works best on small images.
#Note that you can process a small imageto obtain the chrominance map and then rescale it and combine it with the original
#grayscale image for higher quality.
#Larger image sizes can give uneven colorings (limited by spatial support of the network).

# %%
# loading image paths
import os
import glob #glob finds all the file paths that match a specified pattern
from pathlib import Path
import matplotlib.pyplot as plt
from PIL import Image

#train_path = "\C:\Users\batpot\Desktop\RI\datasets\coco\train\/"
#test_path = "/RI/datasets/coco/test/"
#val_path = "/RI/datasets/coco/val/"

#def get_images_paths(directory):
#    print(os.path.join(directory, "*.jpg"))
#    return glob(os.path.join(directory, "*.jpg"))

train_paths = glob.glob(r"C:\Users\batpot\Desktop\RI\datasets\coco\train\*.jpg")
val_paths = glob.glob(r"C:\Users\batpot\Desktop\RI\datasets\coco\val\*.jpg")

#print(train_paths[:5])

#train_paths = get_images_paths(train_path)
#val_paths = get_images_paths(val_path)
print(len(train_paths), len(val_paths))

#_, axes = plt.subplots(4, 4, figsize=(10, 10))
#for ax, img_path in zip(axes.flatten(), train_paths):
#    ax.imshow(Image.open(img_path))
#    ax.axis("off")

# %%
# preprocess images
import PIL
import PIL.Image as PILI
from skimage.color import rgb2lab, lab2rgb

def preprocess_image(image_path, size=(224, 224)):
    img_path = Path(image_path)
    #print(img_path.exists())
    img = PIL.Image.open(img_path).convert('RGB')

    img = img.resize(size, Image.BICUBIC)

    img_rgb = np.asarray(img)
    img_lab = rgb2lab(img)

    L = img_lab[:, :, 0] / 100.0  # Normalize L channel to [0,1]
    ab = (img_lab[:, :, 1:3] + 128) / 255.0  # Normalize a and b to [0,1]

    L = torch.from_numpy(L).unsqueeze(0).float()         # shape: 1 x H x W
    ab = torch.from_numpy(ab).permute(2, 0, 1).float()   # shape: 2 x H x W

    #print(img)
    #print(L)
    #print(ab)
    return L, ab

# %%
import numpy as np
def load_dataset(image_paths, max_images=None):
    L_list, ab_list = [], []
    for i, path in enumerate(image_paths):
        if max_images and i >= max_images:
            break
        L, ab = preprocess_image(path)
        L_list.append(L)
        ab_list.append(ab)
    return np.array(L_list), np.array(ab_list)

# %%
X_train, Y_train = load_dataset(train_paths, max_images=10000)
X_val, Y_val = load_dataset(val_paths, max_images=2000)

# %%
#X_train, Y_train

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import os
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

from matplotlib import pyplot as plt
from PIL import Image
from sklearn.model_selection import train_test_split

batch_size = 32
img_size = 120
dataset_split = 2500

dir = 'drive/MyDrive/train'
X = []
y = []

# %%
for image_path in os.listdir(dir)[:dataset_split]:
    try:
        image_rgb = Image.open(os.path.join(dir, image_path)).resize((img_size, img_size)).convert('RGB') # shape (120, 120, 3)
        image_rgb_array = np.asarray(image_rgb, dtype="float32") / 255.0 #normalizacija

        image_gray = image_rgb.convert('L')
        image_gray_array = np.asarray(image_gray, dtype="float32")

        if image_gray_array.shape != (img_size, img_size):
            #print(f"greska {image_path}: {image_gray_array.shape}")
            continue

        # dodajemo za boje dimenziju jer je bw oblika (visina, sirina, 1) tj. samo (visina, sirina)
        image_gray_array = image_gray_array.reshape((img_size, img_size, 1)) / 255.0 # shape (120, 120, 1) ~ (height, width, num_color_chanels)

        X.append(image_gray_array)
        y.append(image_rgb_array)

    except Exception as e:
        print(f"greska {image_path}: {e}")

# %%
X = np.array(X, dtype="float32")
y = np.array(y, dtype="float32")

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
#dataset = dataset.map(augment)
dataset = dataset.batch(batch_size)
dataset = dataset.shuffle(1000)
dataset # is a batched, iterable TensorFlow dataset containing grayscale
        # input images and RGB target images, ready to feed into your training loop efficiently.
# Out:
# <_ShuffleDataset element_spec=(TensorSpec(shape=(None, 120, 120, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None, 120, 120, 3), dtype=tf.float32, name=None))>

# %%
X_train.shape

# %%
y_train.shape

# %%
print(f"X.shape: {X.shape}")
print(f"y.shape: {y.shape}")
print(f"X_test shape:, {X_test.shape}")
print(f"y_test shape:, {y_test.shape}")

# %%
# def generator_model():
#     inputs = tf.keras.layers.Input(shape=(img_size, img_size, 1))

#     x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
#     x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', strides=2)(x)
#     x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same', strides=2)(x)

#     x = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)

#     x = tf.keras.layers.Conv2DTranspose(128, (3, 3), activation='relu', padding='same', strides=2)(x)
#     x = tf.keras.layers.Conv2DTranspose(64, (3, 3), activation='relu', padding='same', strides=2)(x)
#     x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)

#     outputs = tf.keras.layers.Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)

#     model = tf.keras.models.Model(inputs, outputs)
#     return model
# implementing the generator
def generator_model():
    inputs = tf.keras.layers.Input(shape=(img_size, img_size, 1))

    # conv1 block
    conv1 = tf.keras.layers.Conv2D(16, (5, 5), strides=1, padding='same')(inputs)
    conv1 = tf.keras.layers.LeakyReLU()(conv1)
    conv1 = tf.keras.layers.Conv2D(32, (3, 3), strides=1, padding='same')(conv1)
    conv1 = tf.keras.layers.LeakyReLU()(conv1)
    conv1 = tf.keras.layers.Conv2D(32, (3, 3), strides=1, padding='same')(conv1)
    conv1 = tf.keras.layers.LeakyReLU()(conv1)

    # conv2 block
    conv2 = tf.keras.layers.Conv2D(32, (5, 5), strides=1, padding='same')(conv1)
    conv2 = tf.keras.layers.LeakyReLU()(conv2)
    conv2 = tf.keras.layers.Conv2D(64, (3, 3), strides=1, padding='same')(conv2)
    conv2 = tf.keras.layers.LeakyReLU()(conv2)
    conv2 = tf.keras.layers.Conv2D(64, (3, 3), strides=1, padding='same')(conv2)
    conv2 = tf.keras.layers.LeakyReLU()(conv2)

    # conv3 block
    conv3 = tf.keras.layers.Conv2D(64, (5, 5), strides=1, padding='same')(conv2)
    conv3 = tf.keras.layers.LeakyReLU()(conv3)
    conv3 = tf.keras.layers.Conv2D(128, (3, 3), strides=1, padding='same')(conv3)
    conv3 = tf.keras.layers.LeakyReLU()(conv3)
    conv3 = tf.keras.layers.Conv2D(128, (3, 3), strides=1, padding='same')(conv3)
    conv3 = tf.keras.layers.LeakyReLU()(conv3)

    # bottleneck
    #bottleneck = tf.keras.layers.Conv2D(128, (3, 3), strides=1, activation='tanh', padding='same')(conv3)
    bottleneck = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same')(conv3)

    # decoder part
    concat_1 = tf.keras.layers.Concatenate()([bottleneck, conv3])
    conv_up_3 = tf.keras.layers.Conv2DTranspose(128, (3, 3), strides=1, activation='relu', padding='same')(concat_1)
    conv_up_3 = tf.keras.layers.Conv2DTranspose(128, (3, 3), strides=1, activation='relu', padding='same')(conv_up_3)
    conv_up_3 = tf.keras.layers.Conv2DTranspose(64, (5, 5), strides=1, activation='relu', padding='same')(conv_up_3)

    concat_2 = tf.keras.layers.Concatenate()([conv_up_3, conv2])
    conv_up_2 = tf.keras.layers.Conv2DTranspose(64, (3, 3), strides=1, activation='relu', padding='same')(concat_2)
    conv_up_2 = tf.keras.layers.Conv2DTranspose(64, (3, 3), strides=1, activation='relu', padding='same')(conv_up_2)
    conv_up_2 = tf.keras.layers.Conv2DTranspose(32, (5, 5), strides=1, activation='relu', padding='same')(conv_up_2)

    concat_3 = tf.keras.layers.Concatenate()([conv_up_2, conv1])
    conv_up_1 = tf.keras.layers.Conv2DTranspose(32, (3, 3), strides=1, activation='relu', padding='same')(concat_3)
    conv_up_1 = tf.keras.layers.Conv2DTranspose(32, (3, 3), strides=1, activation='relu', padding='same')(conv_up_1)
    conv_up_1 = tf.keras.layers.Conv2DTranspose(3, (5, 5), strides=1, activation='sigmoid', padding='same')(conv_up_1)

    model = tf.keras.models.Model(inputs, conv_up_1)
    return model

# %%
# def discriminator_model():
#     inputs = tf.keras.layers.Input(shape=(img_size, img_size, 3))

#     x = tf.keras.layers.Conv2D(32, (4, 4), strides=2, padding='same')(inputs)
#     x = tf.keras.layers.LeakyReLU(0.2)(x)

#     x = tf.keras.layers.Conv2D(64, (4, 4), strides=2, padding='same')(x)
#     x = tf.keras.layers.BatchNormalization()(x)
#     x = tf.keras.layers.LeakyReLU(0.2)(x)

#     x = tf.keras.layers.Conv2D(128, (4, 4), strides=2, padding='same')(x)
#     x = tf.keras.layers.BatchNormalization()(x)
#     x = tf.keras.layers.LeakyReLU(0.2)(x)

#     x = tf.keras.layers.Conv2D(256, (4, 4), strides=2, padding='same')(x)
#     x = tf.keras.layers.BatchNormalization()(x)
#     x = tf.keras.layers.LeakyReLU(0.2)(x)

#     x = tf.keras.layers.Flatten()(x)
#     x = tf.keras.layers.Dense(1, activation='sigmoid')(x)

#     model = tf.keras.models.Model(inputs, x)
#     return model

# implementig discriminator
def discriminator_model():
    layers = [
        tf.keras.layers.Conv2D(32, kernel_size=(7, 7), strides=1, activation='relu', input_shape=(120, 120, 3)),
        tf.keras.layers.Conv2D(32, kernel_size=(7, 7), strides=1, activation='relu'),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D(64, kernel_size=(5, 5), strides=1, activation='relu'),
        tf.keras.layers.Conv2D(64, kernel_size=(5, 5), strides=1, activation='relu'),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D(128, kernel_size=(3, 3), strides=1, activation='relu'),
        tf.keras.layers.Conv2D(128, kernel_size=(3, 3), strides=1, activation='relu'),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D(256, kernel_size=(3, 3), strides=1, activation='relu'),
        tf.keras.layers.Conv2D(256, kernel_size=(3, 3), strides=1, activation='relu'),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(16, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ]
    model = tf.keras.models.Sequential(layers)
    return model

# %%
vgg = tf.keras.applications.VGG19(include_top=False, weights='imagenet', input_shape=(120, 120, 3))
vgg.trainable = False
feature_extractor = tf.keras.Model(inputs=vgg.input, outputs=vgg.get_layer('block3_conv3').output)
# Out:
# ...
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# loss functions
cross_entropy = tf.keras.losses.BinaryCrossentropy()
mse = tf.keras.losses.MeanSquaredError()

def perceptual_loss(fake_img, real_img):
    # Preprocess for VGG
    fake_img_prep = tf.keras.applications.vgg19.preprocess_input(fake_img * 255.0)
    real_img_prep = tf.keras.applications.vgg19.preprocess_input(real_img * 255.0)

    # Extract features
    fake_features = feature_extractor(fake_img_prep)
    real_features = feature_extractor(real_img_prep)

    return tf.reduce_mean(tf.square(fake_features - real_features))

# def generator_loss(fake_img, real_img, perceptual_weight=0.1):
#     mse_loss = mse(fake_img, real_img)
#     perceptual = perceptual_loss(fake_img, real_img)
#     return mse_loss + perceptual_weight * perceptual

def colorfulness_loss(generated):
  # Encourage a* and b* channel variance (Lab space) or RGB variation
  mean_rgb = tf.reduce_mean(generated, axis=[1,2], keepdims=True)
  color_var = tf.reduce_mean(tf.square(generated - mean_rgb))
  return -color_var  # negative because you want to maximize it

def generator_loss(fake_output, real_y):
  real_y = tf.cast(real_y, 'float32')
  return mse(fake_output, real_y)


def discriminator_loss(real_output, fake_output):
  real_loss = cross_entropy(tf.ones_like(real_output) * 0.9, real_output) # bilo je * 1.0 ali je disc tad bio bas blizy 0
  fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
  return real_loss + fake_loss

generator_optimizer = tf.keras.optimizers.Adam(0.0005)
discriminator_optimizer = tf.keras.optimizers.Adam(0.00005)

generator = generator_model()
discriminator = discriminator_model()


# def discriminator_loss(real_output, fake_output):
#     real_loss = cross_entropy(tf.ones_like(real_output) * 0.9 - tf.random.uniform(shape=real_output.shape, maxval=0.1), real_output)
#     fake_loss = cross_entropy(tf.zeros_like(fake_output) + 0.1 + tf.random.uniform(shape=fake_output.shape, maxval=0.1), fake_output)
#     total_loss = real_loss + fake_loss
#     return total_loss


# gen bude 0 !!!!!!!!
# def generator_loss(fake_output):
#     return 0.5 * tf.reduce_mean((fake_output - 1)**2)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
test_output = generator(tf.random.normal([1, 120, 120, 1]))
print(test_output.shape)
# Out:
# (1, 120, 120, 3)

# %%
#training
@tf.function
def train_step(input_x, real_y):
  #tf.print("train_step shapes:", tf.shape(input_x), tf.shape(real_y))


  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    generated_images = generator(input_x, training=True)
    real_output = discriminator(real_y, training=True)
    generated_output = discriminator(generated_images, training=True)

    # L2 Loss -> || y - G(x) || ^2
    #gen_loss = generator_loss(generated_images, real_y)
    lambda_color = 1.0  # you can tune this
    gen_loss = generator_loss(generated_images, real_y) + lambda_color * colorfulness_loss(generated_images)
    # BCE Loss -> BCE(y, y') = - [ y * log(y') + (1 - y) * log(1 - y') ], y je prava vrednost 0 ili 1, a y' predvidjena (izmedju 0 i 1)
    disc_loss = discriminator_loss(real_output, generated_output)

  gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
  gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

  generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
  discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

  return gen_loss, disc_loss

# %%
# чување слика
os.makedirs("/content/drive/MyDrive/generated_outputs", exist_ok=True)

def save_output_images(epoch, generator, X_test, num_samples=10):
    generated = generator(X_test[:num_samples], training=False).numpy()

    generated = (generated * 255).astype(np.uint8)

    for i in range(num_samples):
        img = Image.fromarray(generated[i])
        img.save(f"/content/drive/MyDrive/generated_outputs/epoch_{epoch:03d}_sample_{i}.png")

# %%
import time

start = time.time()
num_epochs = 40
num_epochs_to_save = 10

g_losses = []
d_losses = []

for e in range(num_epochs):
    print(f"Epoch {e+1} start")
    g_losses_per_epoch = []
    d_losses_per_epoch = []

    for (x, y) in dataset: # idemo kroz batches i za svaki batch treniramo model
        #print(x.shape)
        g_loss, d_loss = train_step(x, y)
        g_losses_per_epoch.append(g_loss.numpy())
        d_losses_per_epoch.append(d_loss.numpy())

        if e % num_epochs_to_save == 0:
          save_output_images(e, generator, X_test)

    # Calculate average loss for this epoch
    avg_gen_loss = sum(g_losses_per_epoch) / len(g_losses_per_epoch)
    avg_disc_loss = sum(d_losses_per_epoch) / len(d_losses_per_epoch)

    g_losses.append(avg_gen_loss)
    d_losses.append(avg_disc_loss)

    # Save weights once per epoch
    print(f"Epoch {e+1} completed in {time.time() - start:.2f} seconds, Generator loss: {avg_gen_loss:.4f}, Discriminator loss: {avg_disc_loss:.4f}")
    start = time.time()
# Out:
# Epoch 1 start
# Epoch 1 completed in 81.90 seconds, Generator loss: 0.0310, Discriminator loss: 0.9794
# Epoch 2 start
# Epoch 2 completed in 81.91 seconds, Generator loss: 0.0133, Discriminator loss: 0.7093
# Epoch 3 start
# Epoch 3 completed in 62.17 seconds, Generator loss: 0.0112, Discriminator loss: 0.6390
# Epoch 4 start
# Epoch 4 completed in 81.91 seconds, Generator loss: 0.0106, Discriminator loss: 0.6620
# Epoch 5 start
# Epoch 5 completed in 60.95 seconds, Generator loss: 0.0097, Discriminator loss: 0.5891
# Epoch 6 start
# Epoch 6 completed in 81.91 seconds, Generator loss: 0.0094, Discriminator loss: 0.5731
# Epoch 7 start
# Epoch 7 completed in 63.12 seconds, Generator loss: 0.0093, Discriminator loss: 0.6655
# Epoch 8 start
# Epoch 8 completed in 81.91 seconds, Generator loss: 0.0090, Discriminator loss: 0.5242
# Epoch 9 start
# Epoch 9 completed in 63.24 seconds, Generator loss: 0.0088, Discriminator loss: 0.5267
# Epoch 10 start
# ...

# %%
for (g, d) in zip(g_losses, d_losses):
  print(f"generator losses: {g}, discriminator_losses: {d}")

# %%
plt.figure(figsize=(10,5))
plt.plot(g_losses, label="Generator Loss")
plt.plot(d_losses, label="Discriminator Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.title("Training Losses Over Epochs")
plt.show()

# %%
# normalizovani gen_loss i disc_loss da se vide uporedo
g_losses = np.array(g_losses)
d_losses = np.array(d_losses)

g_norm = (g_losses - g_losses.min()) / (g_losses.max() - g_losses.min())
d_norm = (d_losses - d_losses.min()) / (d_losses.max() - d_losses.min())

plt.figure(figsize=(10, 5))
plt.plot(g_norm, label='Generator Loss (Normalized)')
plt.plot(d_norm, label='Discriminator Loss (Normalized)')
plt.xlabel('Epoch')
plt.ylabel('Normalized Loss')
plt.title('Normalized Generator vs Discriminator Losses')
plt.legend()
plt.show()

# %%
#OOM greska, mora manje slika odjednom!!!!!!!!!!!!!!
#NE RADI OVO

# y = generator(X_test[0:]).numpy()

# for i in range(len(X_test)):
#   plt.figure(figsize=(10,10))

#   bw_image = plt.subplot(3, 3, 1)
#   bw_image.set_title('Grayscale Input', fontsize = 16)
#   plt.imshow(X_test[i].reshape((120, 120)), cmap='gray')

#   colored_image = plt.subplot(3, 3, 2)
#   image = Image.fromarray((y[i] * 255 ).astype('uint8')).resize((1024, 1024))
#   image = np.asarray(image)
#   colored_image.set_title('Colorized Output', fontsize = 16)
#   plt.imshow(image)

#   og_image = plt.subplot(3,3,3)
#   image = Image.fromarray((y_test[i] * 255).astype('uint8' )).resize((1024, 1024))
#   og_image.set_title('OG Image', fontsize=16)
#   plt.imshow( image )

#   plt.show()
#   time.sleep(0.5)A

# %%
chunk_size = 30

num_samples = len(X_test)
num_chunks = (num_samples + chunk_size - 1) // chunk_size

for chunk_idx in range(num_chunks):
    start = chunk_idx * chunk_size
    end = min((chunk_idx + 1) * chunk_size, num_samples)

    x_chunk = X_test[start:end]
    y_chunk = generator(x_chunk).numpy()

    for i in range(len(x_chunk)):
        plt.figure(figsize=(10, 10))

        # Grayscale input
        bw_image = plt.subplot(3, 3, 1)
        bw_image.set_title('Grayscale Input', fontsize=16)
        plt.imshow(x_chunk[i].reshape((120, 120)), cmap='gray')

        # Colorized output
        colored_image = plt.subplot(3, 3, 2)
        image = Image.fromarray((y_chunk[i] * 255).astype('uint8')).resize((1024, 1024))
        colored_image.set_title('Colorized Output', fontsize=16)
        plt.imshow(image)

        # Original RGB image
        og_image = plt.subplot(3, 3, 3)
        image = Image.fromarray((y_test[start + i] * 255).astype('uint8')).resize((1024, 1024))
        og_image.set_title('OG Image', fontsize=16)
        plt.imshow(image)

        plt.show()
    #    time.sleep(0.5)
    #break
